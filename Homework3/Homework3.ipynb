# %% [markdown]
# <a href="https://colab.research.google.com/github/travlake/ai-investments-course/blob/main/Homework/Homework3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework 3
#
# **Due 11:59pm on Monday 2/9/2026**
#
# Finance 372T/397 "AI Powered Investments" \
# Professor Travis Johnson \
# McCombs School of Business, The University of Texas at Austin
#
# ## Grading
#
# Your submission will be evaluated on:
#
# - **Sources**: Did you identify the *correct* primary texts?
#
# - **Textual precision**: Did you point to *specific language*, not vague themes?
#
# - **Economic interpretation**: Did you clearly link text to belief revision and prices?
#
# - **Clarity and structure**: Is your analysis concise, organized, and readable?
#
# - **Judgment**: Do you demonstrate an understanding of why markets reacted *as they did*, not just *that* they reacted?
#
# ## Deliverable
#
# 3-5 pages written in a word processor (not this notebook). You will submit your write-up as a **PDF file on Canvas**.

# %% [markdown]
# ## Objective
#
# This assignment examines **how market-moving information is often embedded in text** rether than tabulated numbers.
#
# Across four recent real-world cases, you will trace:
# - The **original textual source**
# - How that text was **interpreted**
# - How market prices **reacted**
#
# You may use AI tools but you are responsible for selecting the relevant materials, identifying the *specific* phrases that mattered, explaining the mechanism through which text affects prices.
#
# You are also responsible for writing specific and concise summaries that convey the key information without fluff.
#
# Generic summaries will receive little credit.

# %% [markdown]
# -----
#
# ## Question 1: TSLA Earnings
#
# **Event Date:** January 28, 2026
#
# Analyze the Q4 earnings release and earnings call materials from Tesla’s investor relations site:
# > https://ir.tesla.com/#quarterly-disclosure
#
# Pay particular attention to:
# - The earnings press release
# - Shareholder deck
# - **Earnings call/webcast transcript,** which you can find here:
# > https://finance.yahoo.com/quote/TSLA/earnings/TSLA-Q4-2025-earnings_call-393464.html
#
# ### Task
#
# Summarize the financial performance and any other economically important news from this event.
#
# Be sure to:
# - Cite where each piece of key performance and economic news can be found
# - Explain how the type of information conveyed, tone, and target audiences differ between the 10-K, press release, shareholder deck, and earnings call
# - Discuss what follow-on reporting indicated was the most relevant to price movements
# - Provide concrete information on how TSLA's stock prices reacted overnight to the news

# %% [markdown]
# ---
#
# ## Question 2: GOOGL Product Rollout
#
# **Event Date:** February 8, 2023
#
# On this date, Alphabet stock experienced a sharp decline.
#
# ### Task
#
# Reconstruct what happened by:
# - Locating and providing the **original product rollout materials**
# - Identifying the specific moment or claim that triggered concern
# - Summarizing the **immediate market reaction**, including quantiative details
#
# Then answer:
# - Why was the reaction so fast and large?
# - Why did follow-on analysis amplify rather than reverse the move?

# %% [markdown]
# ---
#
# ## Question 3: Jerome Powell at Jackson Hole
#
# **Event Date:** August 26, 2022
#
# ### Task
#
# Read this transcript of Jerome Powell's speech at Jackson Hole:
# > https://www.federalreserve.gov/newsevents/speech/powell20220826a.htm
#
# Or watch this 10 minute video of the speech:
# > https://www.youtube.com/watch?v=uracufQnNYQ
#
# **WITHOUT** AI assistance or looking up the surrounding news:
# - What do you think the key phrase(s) were?
# - How would you guess markets will react?
#
# **WITH** AI assistance and/or looking up the surrounding news:
# - What were the key phrase(s) markets responded to?
# - What relevant context from the 2022 market environment shapes how markets read this speech?
# - How did market prices respond?
# - Why did this language matter *more* than new data?
#
# Be sure to clearly delineate in your write-up your initial impression (without AI assistance or supplemental news) and final description (with AI assistance and supplemental news).

# %% [markdown]
# ---
#
# ## Question 4: SVB’s Mid-Quarter Update
#
# **Event Date:** March 8, 2023
#
# Analyze Silicon Valley Bank’s **Mid-Quarter Update** PDF released on this date.
#
# ### Task
#
# Your goal is to:
# - Translate the financial and regulatory language into plain English
# - Explain why the document was *much worse news than it appeared*
#
# Specifically address:
# - What information this update revealed implicitly
# - Why context (rates, deposits, duration risk) is essential
# - What happened later that night that affected SVB's business?
# - What happened overnight and at the market open to SVB's share price?
